# %%
from langchain_unstructured import UnstructuredLoader

file_path = "0.pdf"

loader_local = UnstructuredLoader(
    file_path=file_path,
    strategy="hi_res", # 高分辨率模式，支持复杂文档
    infer_table_structure=True, # 自动解析表格结构
    languages=["chi_sim","eng"], # 支持中英文 OCR
    ocr_engine="paddleocr" # 指定 PaddleOCR 作为 OCR 引擎
)

docs_local = []
for doc in loader_local.lazy_load():
	docs_local.append(doc)
    
docs_local
# Out:
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# INFO: Reading PDF for file: 0.pdf ...
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured_pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File D:\Programs\Python\Python312\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File D:\Programs\Python\Python312\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] 系统找不到指定的文件。
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[3], line 14
#       5 loader_local = UnstructuredLoader(
#       6     file_path=file_path,
#       7     strategy="hi_res", # 高分辨率模式，支持复杂文档
#    (...)     10     ocr_engine="paddleocr" # 指定 PaddleOCR 作为 OCR 引擎
#      11 )
#      13 docs_local = []
# ---> 14 for doc in loader_local.lazy_load():
#      15 	docs_local.append(doc)
#      17 docs_local
#
# File D:\Programs\Python\Python312\Lib\site-packages\langchain_unstructured\document_loaders.py:178, in UnstructuredLoader.lazy_load(self)
#     175     return
#     177 # Call _UnstructuredBaseLoader normally since file and file_path are not lists
# --> 178 yield from load_file(f=self.file, f_path=self.file_path)
#
# File D:\Programs\Python\Python312\Lib\site-packages\langchain_unstructured\document_loaders.py:212, in _SingleDocumentLoader.lazy_load(self)
#     207 def lazy_load(self) -> Iterator[Document]:
#     208     """Load file."""
#     209     elements_json = (
#     210         self._post_process_elements_json(self._elements_json)
#     211         if self.post_processors
# --> 212         else self._elements_json
#     213     )
#     214     for element in elements_json:
#     215         metadata = self._get_metadata()
#
# File D:\Programs\Python\Python312\Lib\site-packages\langchain_unstructured\document_loaders.py:231, in _SingleDocumentLoader._elements_json(self)
#     228 if self.partition_via_api:
#     229     return self._elements_via_api
# --> 231 return self._convert_elements_to_dicts(self._elements_via_local)
#
# File D:\Programs\Python\Python312\Lib\site-packages\langchain_unstructured\document_loaders.py:249, in _SingleDocumentLoader._elements_via_local(self)
#     243 if self.file and self.unstructured_kwargs.get("metadata_filename") is None:
#     244     raise ValueError(
#     245         "If partitioning a fileIO object, metadata_filename must be specified"
#     246         " as well.",
#     247     )
# --> 249 return partition(
#     250     file=self.file, filename=self.file_path, **self.unstructured_kwargs
#     251 )
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\auto.py:212, in partition(filename, file, encoding, content_type, url, headers, ssl_verify, request_timeout, strategy, skip_infer_table_types, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, data_source_metadata, metadata_filename, hi_res_model_name, model_name, starting_page_number, **kwargs)
#     210 if file_type == FileType.PDF:
#     211     partition_pdf = partitioner_loader.get(file_type)
# --> 212     elements = partition_pdf(
#     213         filename=filename,
#     214         file=file,
#     215         url=None,
#     216         infer_table_structure=infer_table_structure,
#     217         strategy=strategy,
#     218         languages=languages,
#     219         detect_language_per_element=detect_language_per_element,
#     220         hi_res_model_name=hi_res_model_name or model_name,
#     221         extract_images_in_pdf=extract_images_in_pdf,
#     222         extract_image_block_types=extract_image_block_types,
#     223         extract_image_block_output_dir=extract_image_block_output_dir,
#     224         extract_image_block_to_payload=extract_image_block_to_payload,
#     225         starting_page_number=starting_page_number,
#     226         **kwargs,
#     227     )
#     228     return augment_metadata(elements)
#     230 if file_type.partitioner_shortname and file_type.partitioner_shortname == "image":
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\common\metadata.py:162, in apply_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     160 @functools.wraps(func)
#     161 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 162     elements = func(*args, **kwargs)
#     163     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     165     # ------------------------------------------------------------------------------------
#     166     # unique-ify elements
#     167     # ------------------------------------------------------------------------------------
#    (...)    172     # instance).
#     173     # ------------------------------------------------------------------------------------
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf.py:225, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, detect_language_per_element, metadata_last_modified, chunking_strategy, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, starting_page_number, extract_forms, form_extraction_skip_tables, password, pdfminer_line_margin, pdfminer_char_margin, pdfminer_line_overlap, pdfminer_word_margin, **kwargs)
#     222 exactly_one(filename=filename, file=file)
#     224 languages = check_language_args(languages or [], ocr_languages)
# --> 225 return partition_pdf_or_image(
#     226     filename=filename,
#     227     file=file,
#     228     include_page_breaks=include_page_breaks,
#     229     strategy=strategy,
#     230     infer_table_structure=infer_table_structure,
#     231     languages=languages,
#     232     detect_language_per_element=detect_language_per_element,
#     233     metadata_last_modified=metadata_last_modified,
#     234     hi_res_model_name=hi_res_model_name,
#     235     extract_images_in_pdf=extract_images_in_pdf,
#     236     extract_image_block_types=extract_image_block_types,
#     237     extract_image_block_output_dir=extract_image_block_output_dir,
#     238     extract_image_block_to_payload=extract_image_block_to_payload,
#     239     starting_page_number=starting_page_number,
#     240     extract_forms=extract_forms,
#     241     form_extraction_skip_tables=form_extraction_skip_tables,
#     242     password=password,
#     243     pdfminer_line_margin=pdfminer_line_margin,
#     244     pdfminer_char_margin=pdfminer_char_margin,
#     245     pdfminer_line_overlap=pdfminer_line_overlap,
#     246     pdfminer_word_margin=pdfminer_word_margin,
#     247     **kwargs,
#     248 )
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf.py:340, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, languages, detect_language_per_element, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, starting_page_number, extract_forms, form_extraction_skip_tables, password, pdfminer_line_margin, pdfminer_char_margin, pdfminer_line_overlap, pdfminer_word_margin, ocr_agent, table_ocr_agent, **kwargs)
#     338 with warnings.catch_warnings():
#     339     warnings.simplefilter("ignore")
# --> 340     elements = _partition_pdf_or_image_local(
#     341         filename=filename,
#     342         file=spooled_to_bytes_io_if_needed(file),
#     343         is_image=is_image,
#     344         infer_table_structure=infer_table_structure,
#     345         include_page_breaks=include_page_breaks,
#     346         languages=languages,
#     347         ocr_languages=ocr_languages,
#     348         metadata_last_modified=metadata_last_modified or last_modified,
#     349         hi_res_model_name=hi_res_model_name,
#     350         pdf_text_extractable=pdf_text_extractable,
#     351         extract_images_in_pdf=extract_images_in_pdf,
#     352         extract_image_block_types=extract_image_block_types,
#     353         extract_image_block_output_dir=extract_image_block_output_dir,
#     354         extract_image_block_to_payload=extract_image_block_to_payload,
#     355         starting_page_number=starting_page_number,
#     356         extract_forms=extract_forms,
#     357         form_extraction_skip_tables=form_extraction_skip_tables,
#     358         password=password,
#     359         pdfminer_config=pdfminer_config,
#     360         ocr_agent=ocr_agent,
#     361         table_ocr_agent=table_ocr_agent,
#     362         **kwargs,
#     363     )
#     364     # NOTE(crag): do not call _process_uncategorized_text_elements here, because
#     365     # extracted elements (which are text blocks outside of OD-determined blocks)
#     366     # are likely not Titles and should not be identified as such.
#     367     return elements
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf.py:691, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_languages, ocr_mode, model_name, hi_res_model_name, pdf_image_dpi, metadata_last_modified, pdf_text_extractable, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, analysis, analyzed_image_output_dir_path, starting_page_number, extract_forms, form_extraction_skip_tables, pdf_hi_res_max_pages, password, pdfminer_config, ocr_agent, table_ocr_agent, **kwargs)
#     684     # NOTE(christine): merged_document_layout = extracted_layout + inferred_layout
#     685     merged_document_layout = merge_inferred_with_extracted_layout(
#     686         inferred_document_layout=inferred_document_layout,
#     687         extracted_layout=extracted_layout,
#     688         hi_res_model_name=hi_res_model_name,
#     689     )
# --> 691     final_document_layout = process_file_with_ocr(
#     692         filename,
#     693         merged_document_layout,
#     694         extracted_layout=extracted_layout,
#     695         is_image=is_image,
#     696         infer_table_structure=infer_table_structure,
#     697         ocr_agent=ocr_agent,
#     698         ocr_languages=ocr_languages,
#     699         ocr_mode=ocr_mode,
#     700         pdf_image_dpi=pdf_image_dpi,
#     701         ocr_layout_dumper=ocr_layout_dumper,
#     702         password=password,
#     703         table_ocr_agent=table_ocr_agent,
#     704     )
#     705 else:
#     706     inferred_document_layout = process_data_with_model(
#     707         file,
#     708         is_image=is_image,
#    (...)    711         password=password,
#     712     )
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:201, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, pdf_image_dpi, ocr_layout_dumper, password, table_ocr_agent)
#     199 except Exception as e:
#     200     if os.path.isdir(filename) or os.path.isfile(filename):
# --> 201         raise e
#     202     else:
#     203         raise FileNotFoundError(f'File "{filename}" not found!') from e
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:186, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, pdf_image_dpi, ocr_layout_dumper, password, table_ocr_agent)
#     184     extracted_regions = extracted_layout[i] if i < len(extracted_layout) else None
#     185     with PILImage.open(image_path) as image:
# --> 186         merged_page_layout = supplement_page_layout_with_ocr(
#     187             page_layout=out_layout.pages[i],
#     188             image=image,
#     189             infer_table_structure=infer_table_structure,
#     190             ocr_agent=ocr_agent,
#     191             ocr_languages=ocr_languages,
#     192             ocr_mode=ocr_mode,
#     193             extracted_regions=extracted_regions,
#     194             ocr_layout_dumper=ocr_layout_dumper,
#     195             table_ocr_agent=table_ocr_agent,
#     196         )
#     197         merged_page_layouts.append(merged_page_layout)
#     198 return DocumentLayout.from_pages(merged_page_layouts)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:231, in supplement_page_layout_with_ocr(page_layout, image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, extracted_regions, ocr_layout_dumper, table_ocr_agent)
#     229 _ocr_agent = OCRAgent.get_instance(ocr_agent_module=ocr_agent, language=language)
#     230 if ocr_mode == OCRMode.FULL_PAGE.value:
# --> 231     ocr_layout = _ocr_agent.get_layout_from_image(image)
#     232     if ocr_layout_dumper:
#     233         ocr_layout_dumper.add_ocred_page(ocr_layout.as_list())
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\utils\ocr_models\tesseract_ocr.py:53, in OCRAgentTesseract.get_layout_from_image(self, image)
#      51 trace_logger.detail("Processing entire page OCR with tesseract...")
#      52 zoom = 1
# ---> 53 ocr_df: pd.DataFrame = self.image_to_data_with_character_confidence_filter(
#      54     np.array(image),
#      55     lang=self.language,
#      56     character_confidence_threshold=env_config.TESSERACT_CHARACTER_CONFIDENCE_THRESHOLD,
#      57 )
#      58 ocr_df = ocr_df.dropna()
#      60 # tesseract performance degrades when the text height is out of the preferred zone so we
#      61 # zoom the image (in or out depending on estimated text height) for optimum OCR results
#      62 # but this needs to be evaluated based on actual use case as the optimum scaling also
#      63 # depend on type of characters (font, language, etc); be careful about this
#      64 # functionality
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured\partition\utils\ocr_models\tesseract_ocr.py:99, in OCRAgentTesseract.image_to_data_with_character_confidence_filter(self, image, lang, config, character_confidence_threshold)
#      92 def image_to_data_with_character_confidence_filter(
#      93     self,
#      94     image: np.ndarray,
#    (...)     97     character_confidence_threshold: float = 0.0,
#      98 ) -> pd.DataFrame:
# ---> 99     hocr: str = unstructured_pytesseract.image_to_pdf_or_hocr(
#     100         image,
#     101         lang=lang,
#     102         config="-c hocr_char_boxes=1 " + config,
#     103         extension="hocr",
#     104     )
#     105     ocr_df = self.hocr_to_dataframe(hocr, character_confidence_threshold)
#     106     return ocr_df
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured_pytesseract\pytesseract.py:514, in image_to_pdf_or_hocr(image, lang, config, nice, extension, timeout)
#     510     config = f'-c tessedit_create_hocr=1 {config.strip()}'
#     512 args = [image, extension, lang, config, nice, timeout, True]
# --> 514 return run_and_get_output(*args)
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured_pytesseract\pytesseract.py:353, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     342 with save(image) as (temp_name, input_filename):
#     343     kwargs = {
#     344         'input_filename': input_filename,
#     345         'output_filename_base': temp_name,
#    (...)    350         'timeout': timeout,
#     351     }
# --> 353     run_tesseract(**kwargs)
#     354     return _read_output(
#     355         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     356         return_bytes,
#     357     )
#
# File D:\Programs\Python\Python312\Lib\site-packages\unstructured_pytesseract\pytesseract.py:280, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     278         raise
#     279     else:
# --> 280         raise TesseractNotFoundError()
#     282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

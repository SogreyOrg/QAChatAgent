# %%
# 配置 poppler 路径
import os
poppler_path = r"E:\Programs\poppler-25.07.0\Library\bin"
# 临时添加到系统路径
os.environ["PATH"] = poppler_path + os.pathsep + os.environ["PATH"]
print("✅ Poppler 路径已配置")
# Out:
# ✅ Poppler 路径已配置

# %%
from langchain_unstructured import UnstructuredLoader

file_path = "0.pdf"

loader_local = UnstructuredLoader(
    file_path=file_path,
    strategy="hi_res", # 高分辨率模式，支持复杂文档
    infer_table_structure=True, # 自动解析表格结构
    languages=["chi_sim","eng"], # 支持中英文 OCR
    ocr_engine="paddleocr", # 指定 PaddleOCR 作为 OCR 引擎
    poppler_path=poppler_path # 明确指定 poppler 路径
)

docs_local = []
for doc in loader_local.lazy_load():
    docs_local.append(doc)
    
docs_local
# Out:
# INFO: pikepdf C++ to Python logger bridge initialized
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# INFO: Reading PDF for file: 0.pdf ...
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# INFO: Loading the Table agent ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# INFO: Loading the table structure model ...
# INFO: Loading pretrained weights from Hugging Face hub (timm/resnet18.a1_in1k)
# INFO: [timm/resnet18.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO: Missing keys (fc.weight, fc.bias) discovered while loading pretrained weights. This is expected if model is being adapted.
# [Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.5556954145431519, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(109.24374389648438)), (np.float64(206.944447643981), np.float64(190.77667236328125)), (np.float64(1419.0304636253566), np.float64(190.77667236328125)), (np.float64(1419.0304636253566), np.float64(109.24374389648438))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 1, 'filename': '0.pdf', 'category': 'Title', 'element_id': '2edbca333bf3a312f2c4b6b32de79d32'}, page_content='LangChain快速入门与Agent开发实战-Part'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(197.1930639626584)), (np.float64(206.944447643981), np.float64(258.13056532359565)), (np.float64(241.72762095205508), np.float64(258.13056532359565)), (np.float64(241.72762095205508), np.float64(197.1930639626584))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '2edbca333bf3a312f2c4b6b32de79d32', 'category': 'UncategorizedText', 'element_id': '940da8c2ebb9b07281b53ce4874b4c2a'}, page_content='1'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8058719635009766, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(286.4912414550781)), (np.float64(206.944447643981), np.float64(343.7466154127703)), (np.float64(892.3504028320312), np.float64(343.7466154127703)), (np.float64(892.3504028320312), np.float64(286.4912414550781))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie', 'tgl'], 'page_number': 1, 'filename': '0.pdf', 'category': 'Title', 'element_id': 'ffd05c855856dc3b0248e361306da494'}, page_content='一、LangChain.ai工具生态介绍'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8051451444625854, 'coordinates': {'points': ((np.float64(258.3881530761719), np.float64(375.5347595214844)), (np.float64(258.3881530761719), np.float64(411.4548034667969)), (np.float64(1146.4901665438324), np.float64(411.4548034667969)), (np.float64(1146.4901665438324), np.float64(375.5347595214844))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie', 'zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': 'ffd05c855856dc3b0248e361306da494', 'category': 'NarrativeText', 'element_id': 'a6e8eee39567b00ada6bc21a4d6c5f67'}, page_content='本期公开课，我将为大家详细讲解元老级Agent开发工具——LangChain。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8421537280082703, 'coordinates': {'points': ((np.float64(203.07470703125), np.float64(446.49908447265625)), (np.float64(203.07470703125), np.float64(502.474609375)), (np.float64(900.1676025390625), np.float64(502.474609375)), (np.float64(900.1676025390625), np.float64(446.49908447265625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho', 'kor'], 'page_number': 1, 'filename': '0.pdf', 'category': 'Title', 'element_id': '0f0664722af308de73569ad1ee8456b8'}, page_content='1. GPT-3时代下第一代大模型开发工具'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9442940354347229, 'coordinates': {'points': ((np.float64(204.3675537109375), np.float64(531.4490966796875)), (np.float64(204.3675537109375), np.float64(745.1666259765625)), (np.float64(1449.971923828125), np.float64(745.1666259765625)), (np.float64(1449.971923828125), np.float64(531.4490966796875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'NarrativeText', 'element_id': '6cedb9620b1165faf0354c4feedf4213'}, page_content='LangChain 可以称之为自 2022年底 大模型技术爆火以来的第一个真正意义上的大模型开发框架。大 模型本质上无法直接解决实际的问题，仅仅是一个能够分析、推理和生成文本的黑盒。直到现在，所有 的开发者们仍然在不断探索如何把大模型的强大能力与实际应用场景结合起来，而当时 LangChain 的出 现，直接让大模型开发变得简单起来，它将大模型开发过程中常用的功能、工具、流程等等全部封装成 一个个的组件，使开发者可以像搭乐高积木一样，快速的组合出适用于不同场景需求的大模型应用。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.5947710275650024, 'coordinates': {'points': ((np.float64(249.71957397460938), np.float64(776.2454223632812)), (np.float64(249.71957397460938), np.float64(807.7826772085327)), (np.float64(1396.8858908860027), np.float64(807.7826772085327)), (np.float64(1396.8858908860027), np.float64(776.2454223632812))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'NarrativeText', 'element_id': 'b069cd67298f1647945f5fc01fa00797'}, page_content='LangChain 的首个版本于 2022年10月 开源，直到现在仍然再以一个飞快的速度不断进行迭代升'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.44788748025894165, 'coordinates': {'points': ((np.float64(197.46783447265625), np.float64(820.5191040039062)), (np.float64(197.46783447265625), np.float64(854.9057006835938)), (np.float64(1416.6768798828125), np.float64(854.9057006835938)), (np.float64(1416.6768798828125), np.float64(820.5191040039062))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'ListItem', 'element_id': 'f4df1dd8648a21f802f90facefd652d0'}, page_content='级。从一个开源 Python/TS 框架逐渐发展，形成包括“链”和“代理”等核心组件，现在已走向企业级阶'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.2873983383178711, 'coordinates': {'points': ((np.float64(192.71932983398438), np.float64(866.380126953125)), (np.float64(192.71932983398438), np.float64(902.3143310546875)), (np.float64(1439.169189453125), np.float64(902.3143310546875)), (np.float64(1439.169189453125), np.float64(866.380126953125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho', 'kor'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'ListItem', 'element_id': '397bcc35e675514e8269dc06f4b67db0'}, page_content='段，发展成了 LangChain AI ，其拥有目前 Agent 技术领域最大的开源生态，衍生出了多个开源项目框'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8038997054100037, 'coordinates': {'points': ((np.float64(203.93341064453125), np.float64(907.1635131835938)), (np.float64(203.93341064453125), np.float64(945.3637084960938)), (np.float64(945.2297832781845), np.float64(945.3637084960938)), (np.float64(945.2297832781845), np.float64(907.1635131835938))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'ListItem', 'element_id': 'f55dae123aa9b222a6cf46987f82571e'}, page_content='架，各自都在大模型的技术领域承担着不同的开发任务角色。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9315150380134583, 'coordinates': {'points': ((np.float64(200.3972930908203), np.float64(974.3546142578125)), (np.float64(200.3972930908203), np.float64(1095.2826836293655)), (np.float64(1455.8394775390625), np.float64(1095.2826836293655)), (np.float64(1455.8394775390625), np.float64(974.3546142578125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': '0f0664722af308de73569ad1ee8456b8', 'category': 'NarrativeText', 'element_id': '461d390a8bbf0393eb235756bbb02c3b'}, page_content='从一个形象的角度来说，LangChain的功能定位其实并不是我们现在所谓的Agent开发框架，而是一 个大模型功能增强器，借助LangChain，哪怕在GPT-3模型时代，也能让模型完成对话、拥有记忆、甚至 是完成结构化输出等功能。'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(1121.52787326967)), (np.float64(206.94445137731415), np.float64(1740.2779274884165)), (np.float64(1448.6111329745333), np.float64(1740.2779274884165)), (np.float64(1448.6111329745333), np.float64(1121.52787326967))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 1, 'filename': '0.pdf', 'category': 'Image', 'element_id': '0b884400e486d6d4a720df35aa287588'}, page_content='XD Langchain The platform for reliable agents. p of the agent development lifecycle werful Al in production.'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.6346557140350342, 'coordinates': {'points': ((np.float64(224.63629150390625), np.float64(1768.4249267578125)), (np.float64(224.63629150390625), np.float64(1800.2957202079874)), (np.float64(823.7564086914062), np.float64(1800.2957202079874)), (np.float64(823.7564086914062), np.float64(1768.4249267578125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie', 'tgl'], 'page_number': 1, 'filename': '0.pdf', 'category': 'FigureCaption', 'element_id': 'da453fb03081871529078e4aa822caf0'}, page_content='LangChain官网：https://www.langchain.com/'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8286136984825134, 'coordinates': {'points': ((np.float64(206.2257080078125), np.float64(1831.6905517578125)), (np.float64(206.2257080078125), np.float64(1891.72412109375)), (np.float64(619.7522583007812), np.float64(1891.72412109375)), (np.float64(619.7522583007812), np.float64(1831.6905517578125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'category': 'Title', 'element_id': 'e94bb01ac3ac0ce4b356e3a2716207b0'}, page_content='2. 备受争议的工具功能'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9439979791641235, 'coordinates': {'points': ((np.float64(200.76951599121094), np.float64(1919.9114990234375)), (np.float64(200.76951599121094), np.float64(2129.99755859375)), (np.float64(1444.0274658203125), np.float64(2129.99755859375)), (np.float64(1444.0274658203125), np.float64(1919.9114990234375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 1, 'filename': '0.pdf', 'parent_id': 'e94bb01ac3ac0ce4b356e3a2716207b0', 'category': 'NarrativeText', 'element_id': '5c5a7e7ab7d8d3b3bb259fe770396490'}, page_content='虽说LangChain的开源，在短时间内收获了大量的开发者用户，这也一度使得LangChain在2023年 成为最受欢迎的大模型开发工具没有之一。但每项技术都会受限于其诞生的时代背景，LangChain也不 例外。在GPT-3时代，大模型以补全模型为主，只能以类似“成语接龙”的方式对文本进行补全，并且实际 运行效果也非常不稳定。此时LangChain借助一些高层封装的API，能够让模型完成对话、调用外部工 具、甚至是结构化输出等功能，这在当时是非常大的进步，也为开发者提供了极大的便利。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9458469748497009, 'coordinates': {'points': ((np.float64(204.87783813476562), np.float64(81.64627838134766)), (np.float64(204.87783813476562), np.float64(289.0326909564499)), (np.float64(1444.459733615152), np.float64(289.0326909564499)), (np.float64(1444.459733615152), np.float64(81.64627838134766))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 2, 'filename': '0.pdf', 'parent_id': 'e94bb01ac3ac0ce4b356e3a2716207b0', 'category': 'NarrativeText', 'element_id': '9365ef4e910b2b1f4f242da3d2eba035'}, page_content='但是，伴随着GPT-3.5模型的发布，对话模型正式登上历史的舞台，并逐渐成为主流。而得益于对话 模型更强的指令跟随能力，很多GPT-3需要借助LangChain才能完成的工作，已经成为GPT-3.5原生自带 的一些功能。而等到GPT-4逐渐普及，包括调用外部工具（Function calling）、结构化输出、系统提示 词等功能，都成了模型的基础功能。而对于开发者而言，此时再使用LangChain再对这些功能进行封装 就显得多此一举。'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(354.8611118807864), np.float64(315.27782019675686)), (np.float64(354.8611118807864), np.float64(936.1112076620313)), (np.float64(1309.0278187905053), np.float64(936.1112076620313)), (np.float64(1309.0278187905053), np.float64(315.27782019675686))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 2, 'filename': '0.pdf', 'category': 'Image', 'element_id': '23a7639fafef2f29035540db63e9bf8b'}, page_content='GPTAMBUEARSCARAZO7: GPTERBF Chat AetBA TIME Completion Models Chat Completion Models max_tokens ) response. [2]. [\'content\'] response[ "choices" ][2]["text"]. 6) “lt %, AHtARAY go "JeTEHE\\ n\\n fc, WK. * Chath ee RHR izes Completion*2H Mets TNS'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.516327977180481, 'coordinates': {'points': ((np.float64(246.527781861342), np.float64(963.7035522460938)), (np.float64(246.527781861342), np.float64(996.46484375)), (np.float64(1309.0196670278242), np.float64(996.46484375)), (np.float64(1309.0196670278242), np.float64(963.7035522460938))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 2, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': '410953bcafa4e5fe22fb3d25b023f2d3'}, page_content='【考古】补全模型与对话模型对比介绍：https://www.bilibili.com/video/BV1Vk4y1V76h'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9332827925682068, 'coordinates': {'points': ((np.float64(199.29861450195312), np.float64(1027.1507568359375)), (np.float64(199.29861450195312), np.float64(1193.0196533203125)), (np.float64(1430.4023187178695), np.float64(1193.0196533203125)), (np.float64(1430.4023187178695), np.float64(1027.1507568359375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 2, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': 'f8809f6b35397f316bc4f5c72d1b04cc'}, page_content='因此在2023年下半年起的很长一段时间里，LangChain饱受争议，很多开发者觉得LangChain代码 冗余、编写复杂，甚至有开发者觉得LangChain太过于复杂，一个模型调用的过程就涉及到数十个类， 一个项目开发动辄就要用到几十个不同的类，而说明文档更是几百个不同的常用类需要记住，其复杂程 度不亚于学习一门全新的编程语言。'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(269.4444487731475), np.float64(1217.3612026099477)), (np.float64(269.4444487731475), np.float64(1746.5279272279997)), (np.float64(1386.1112289120297), np.float64(1746.5279272279997)), (np.float64(1386.1112289120297), np.float64(1217.3612026099477))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 2, 'filename': '0.pdf', 'category': 'Image', 'element_id': '1e31525d166ce66a775023603b6b5b12'}, page_content='1. "EERE, RAS, HHP" 3B Reddit Esai Titi€: “The framework feels bloated, with too many dependencies and unnecessary complexity.” tedditcom reddit.com Rnirietign: “It\'s unstable, the interface constantly changes, the documentation is regularly out of date, and the abstractions are overly complicated.” tedditcom APs: “LangChain has a reputation for getting in the way and not actually making your code more efficient ... It is my own framework, but it is extremely, extremely lightweight, developer-centric and transparent.” — redditcom'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(271.52778201967527), np.float64(1769.4445529398072)), (np.float64(271.52778201967527), np.float64(2192.361241984944)), (np.float64(1384.0278156655052), np.float64(2192.361241984944)), (np.float64(1384.0278156655052), np.float64(1769.4445529398072))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 2, 'filename': '0.pdf', 'category': 'Image', 'element_id': '0fdfd0f3d96dc6e066b935e82612439d'}, page_content='2. "HISGRAL, BAAR, WA” As Reddit Heh, AARSHSB: “LangChain is arguably the worst library that I\'ve ever worked in my life. Inconsistent abstraction: ‘onsistent naming schemas, inconsistent behaviour, confusing error management...” reacitcom HPT SAM: ¢ "unnecessary complexity creates a tribalism which hurts the up-and-coming Al ecosystem... Debugging a LangChain error is near impossible, even with verbose=True." minimaxir.com'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(271.52778201967527), np.float64(77.77766342593047)), (np.float64(271.52778201967527), np.float64(421.5276891030123)), (np.float64(1384.0278156655052), np.float64(421.5276891030123)), (np.float64(1384.0278156655052), np.float64(77.77766342593047))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 3, 'filename': '0.pdf', 'category': 'Image', 'element_id': '44b6c32ca1d709ec16409a1f2c912433'}, page_content='3. “SREL. BARRE” 7e/D FAP GitHub Issue Ff] Reddit R28: ° “SOHEBES 3K, ALAM" reddit.com © KARAT. verbose MwA: BABE issue iS verbose (TAA—R , Issue HB KAMARA, SHEE.'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.7990983724594116, 'coordinates': {'points': ((np.float64(260.3575744628906), np.float64(449.4308166503906)), (np.float64(260.3575744628906), np.float64(484.5312805175781)), (np.float64(991.8850589243189), np.float64(484.5312805175781)), (np.float64(991.8850589243189), np.float64(449.4308166503906))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 3, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': '261b8b897aed48ee1780282e1f68abf0'}, page_content='而这也使得在某个时间段，LangChain的开发者大规模流失。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9379482865333557, 'coordinates': {'points': ((np.float64(246.527781861342), np.float64(515.3270263671875)), (np.float64(246.527781861342), np.float64(679.46219384272)), (np.float64(1409.6571044921875), np.float64(679.46219384272)), (np.float64(1409.6571044921875), np.float64(515.3270263671875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie', 'nld', 'est', 'zho'], 'page_number': 3, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': 'aa86d979aab994733ae6ee86961d219a'}, page_content='举个例子，为了更好的兼容不同模型的调用，谷歌ADK采用了LiteLlm作为底层模型调度框架，一 个库即可调用各类模型，而LangChain则为每个主流模型单独封装了一个库，调用不同模型的时候 需要导入不同模型对应的库，例如调用DeepSeek就需要安装 langchain-deepseek ，而调用 Gemini则需要安装 langchain-google-genai 。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8443233966827393, 'coordinates': {'points': ((np.float64(206.92062377929688), np.float64(719.218017578125)), (np.float64(206.92062377929688), np.float64(769.0115356445312)), (np.float64(1159.2122802734375), np.float64(769.0115356445312)), (np.float64(1159.2122802734375), np.float64(719.218017578125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 3, 'filename': '0.pdf', 'category': 'Title', 'element_id': '08dcd581f66b13024dcd6ac9c21269c2'}, page_content='3. 更加适用于当前Agent开发的LangChain工具生态'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8903267979621887, 'coordinates': {'points': ((np.float64(221.78330993652344), np.float64(803.0091552734375)), (np.float64(221.78330993652344), np.float64(877.83984375)), (np.float64(1406.510986328125), np.float64(877.83984375)), (np.float64(1406.510986328125), np.float64(803.0091552734375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'NarrativeText', 'element_id': '11aae97127358fa8f94138bedb4c0d6d'}, page_content='在经历了短暂的阵痛后，LangChain果断进行了大刀阔斧的改革。LangChain调整的思路非常简'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(853.6158435654844)), (np.float64(206.944447643981), np.float64(880.6991775036787)), (np.float64(261.1111155203697), np.float64(880.6991775036787)), (np.float64(261.1111155203697), np.float64(853.6158435654844))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'UncategorizedText', 'element_id': 'a79542cddadd15925ac7ffd99dfe83a2'}, page_content='单：'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9327133893966675, 'coordinates': {'points': ((np.float64(225.8309783935547), np.float64(911.1550903320312)), (np.float64(225.8309783935547), np.float64(1031.7239990234375)), (np.float64(1440.822509765625), np.float64(1031.7239990234375)), (np.float64(1440.822509765625), np.float64(911.1550903320312))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'ListItem', 'element_id': 'fc12dd9b7ec87029497dcbba75aeb4a3'}, page_content='1. LangChain本身仍然坚守作为“模型能力增强器”的功能定位，并且逐渐稳定更新节奏和频率，虽说 实际使用LangChain进行开发的代码量仍然没变，但模块划分更加清晰、功能更加丰富和稳定，逐 步达到企业级应用水准。目前最新版LangChain的核心功能如下：'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.918170690536499, 'coordinates': {'points': ((np.float64(266.9776916503906), np.float64(1075.259033203125)), (np.float64(266.9776916503906), np.float64(1697.065185546875)), (np.float64(1372.15576171875), np.float64(1697.065185546875)), (np.float64(1372.15576171875), np.float64(1075.259033203125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'text_as_html': '<table><tbody><tr><td>RRA</td><td>ARGIDNE</td></tr><tr><td>REROHR</td><td>OpenAl, Claude, Cohere, Qwen Si8@i—ia raya zt</td></tr><tr><td>ma atatt</td><td>TMB Ichi ISON, Schema, PRANSR. SOME</td></tr><tr><td>Memory #2</td><td>Buffer, Summary, Entity, Conversation Memory &amp;</td></tr><tr><td>Tool #2</td><td>Web #228, SQL Sle. Python H4Tes, API (CHES</td></tr><tr><td>Agent 32¢4</td><td>ReAct, Self-Ask, OpenAl Function Agent Si E24)</td></tr><tr><td>RAG SRK</td><td>2 FH Retriever, Vector Store, SCMHRSRES</td></tr><tr><td>Server/API #27</td><td>Riis BE 79 Web ARSSBK A2A Agent</td></tr><tr><td>Debug &amp; Callback</td><td>Token {#F sit. LangSmith AULIBERS</td></tr></tbody></table>', 'filetype': 'application/pdf', 'languages': ['eng', 'nor'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'Table', 'element_id': 'c83b0952b4e404dc9221d2e47e28bac6'}, page_content='模块类别 示例功能 模型接口封装 OpenAI、Claude、Cohere、Qwen 等模型统一调用方式 输出结构化 自动从模型中解析 JSON、Schema、函数签名、文档等 Memory 管理 Buffer、Summary、Entity、Conversation Memory 等 Tool 接入 Web 搜索、SQL 数据库、Python 执行器、API 代理等 Agent 架构 ReAct、Self-Ask、OpenAI Function Agent 等调度机制 RAG 集成 多种 Retriever、Vector Store、文档拆分策略 Server/API 发布 快速将链部署为 Web 服务或 A2A Agent Debug & Callback Token 使用统计、LangSmith 可视化追踪等'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8324888944625854, 'coordinates': {'points': ((np.float64(297.37347412109375), np.float64(1742.3609806016234)), (np.float64(297.37347412109375), np.float64(1822.6290283203125)), (np.float64(1420.697998046875), np.float64(1822.6290283203125)), (np.float64(1420.697998046875), np.float64(1742.3609806016234))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'NarrativeText', 'element_id': 'ff07d10dda8f056f4fa475b5e6bcaa4f'}, page_content='✅ 所以说：LangChain 是 LLM 功能开发的「积木工厂」，不是简单框架，而是模型增强器 + 应用组装工具箱。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8942210078239441, 'coordinates': {'points': ((np.float64(233.01930236816406), np.float64(1856.9095458984375)), (np.float64(233.01930236816406), np.float64(2020.2825362877036)), (np.float64(1455.3843994140625), np.float64(2020.2825362877036)), (np.float64(1455.3843994140625), np.float64(1856.9095458984375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 3, 'filename': '0.pdf', 'parent_id': '08dcd581f66b13024dcd6ac9c21269c2', 'category': 'ListItem', 'element_id': '8fe8efff5c41955b2c40c5b1935840a5'}, page_content='2. 与2023年下半年开源LangGraph，LangGraph作为基于LangChain的更高层次封装，能够更加便捷 的搭建图结构的大模型工作流，也就是现在所谓的Multi-Agent系统，而LangGraph也是目前 LangChian家族最核心的Multi-Agent开发框架。同时可以搭配LangGraph-Studio进行实时效果监 测，实际效果如下所示：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(269.4444487731475), np.float64(754.8612618807791)), (np.float64(269.4444487731475), np.float64(1175.6946176793888)), (np.float64(1448.6111329745333), np.float64(1175.6946176793888)), (np.float64(1448.6111329745333), np.float64(754.8612618807791))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 4, 'filename': '0.pdf', 'category': 'Image', 'element_id': '1b076c9c86aed21b9e588dfffe1559c9'}, page_content='(1 README 48 MiTlicense 18 Security LangGraph pypi (YON) downloads/month 6M) open issues [BAY docs latest) & citmce BREE) Trusted by companies shaping the future of agents — including Klarna, Replit, Elastic, and more — LangGraph is a low- level orchestration framework for building, managing, and deploying long-running, stateful agents.'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.6456699967384338, 'coordinates': {'points': ((np.float64(309.02778325717514), np.float64(1209.5731201171875)), (np.float64(309.02778325717514), np.float64(1241.9623464052129)), (np.float64(982.3770141601562), np.float64(1241.9623464052129)), (np.float64(982.3770141601562), np.float64(1209.5731201171875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 4, 'filename': '0.pdf', 'category': 'Title', 'element_id': '246fc73845be4a820dffb7f58f685a43'}, page_content='项目官网：https://github.com/langchain-ai/langgraph'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8002501726150513, 'coordinates': {'points': ((np.float64(294.8316345214844), np.float64(1264.384521484375)), (np.float64(294.8316345214844), np.float64(1341.9623486385453)), (np.float64(1415.51171875), np.float64(1341.9623486385453)), (np.float64(1415.51171875), np.float64(1264.384521484375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 4, 'filename': '0.pdf', 'parent_id': '246fc73845be4a820dffb7f58f685a43', 'category': 'NarrativeText', 'element_id': 'af4705544bfcafe0424cda706c02e896'}, page_content='需要注意的是，LangGraph底层功能仍然是基于LangChain来实现，简单理解LangGraph本 质上其实就是LangChain的流程调度与智能体编排系统'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9277634620666504, 'coordinates': {'points': ((np.float64(222.22909545898438), np.float64(1346.0833740234375)), (np.float64(222.22909545898438), np.float64(1471.1290181899333)), (np.float64(1453.7891845703125), np.float64(1471.1290181899333)), (np.float64(1453.7891845703125), np.float64(1346.0833740234375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 4, 'filename': '0.pdf', 'parent_id': '246fc73845be4a820dffb7f58f685a43', 'category': 'ListItem', 'element_id': 'eda852e677853447c20056e6c503ea74'}, page_content='3. 开源大模型工作流（Agent）可视化监控与测试平台LangSmith，借助LangSmith，开发者能够更 加简单便捷监控基于LangChain生态的Agent运行流程、测试Agent功能和不同提示词等，从而使得 LangChain进一步面向企业级应用开发框架；'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(269.4444487731475), np.float64(1488.194564658557)), (np.float64(269.4444487731475), np.float64(1975.6945843460553)), (np.float64(1448.6111329745333), np.float64(1975.6945843460553)), (np.float64(1448.6111329745333), np.float64(1488.194564658557))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 4, 'filename': '0.pdf', 'category': 'Image', 'element_id': '28f836b757c262da07e4c1a1dd81bb7c'}, page_content='Email Agent Find failures fast with agent observability. Quickly debug and understand non-deterministic LLM app behavior with tracing. See what your agent is doing step by step —then fix issues to Output improve latency and response quality. Get started tracing your app 1'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.4339856803417206, 'coordinates': {'points': ((np.float64(289.5072937011719), np.float64(2010.7091064453125)), (np.float64(289.5072937011719), np.float64(2041.9623642718773)), (np.float64(1005.82177734375), np.float64(2041.9623642718773)), (np.float64(1005.82177734375), np.float64(2010.7091064453125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['tgl', 'vie', 'eng'], 'page_number': 4, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': '695de0bebd0e0eabe99c518cb0511a3c'}, page_content='LangSmith官网：https://www.langchain.com/langsmith'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.898482620716095, 'coordinates': {'points': ((np.float64(225.36061096191406), np.float64(2077.78564453125)), (np.float64(225.36061096191406), np.float64(2201.037841796875)), (np.float64(1442.44384765625), np.float64(2201.037841796875)), (np.float64(1442.44384765625), np.float64(2077.78564453125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 4, 'filename': '0.pdf', 'category': 'ListItem', 'element_id': '169e1edb44d875cc9a61a661f454da3d'}, page_content='4. 同时，考虑到LangChain本身较为复杂这一情况，开源了LangChain的“可视化实现版”—— LangFlow，这是一款形式对标Dify、可以通过可视化方式、借助拖拉拽来完成LangChain相同功能 的开发工具。'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(269.4444487731475), np.float64(77.77799009258344)), (np.float64(269.4444487731475), np.float64(748.6113754745247)), (np.float64(1448.6111329745333), np.float64(748.6113754745247)), (np.float64(1448.6111329745333), np.float64(77.77799009258344))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 5, 'filename': '0.pdf', 'category': 'Image', 'element_id': 'aee373e825ec22066a57848a09b0c19d'}, page_content='& AstraDbB O~ \\ | 2 Google Search @—_ 2 Analyst @—~ coy Agent Model gpt-40 ® Agent instructions You are the Al News Director @ Tools Playground ra User Give me a brief on key Al trends, research, products, news, and policy—concise summaries only. a Agent Google Search @ Response'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.7556438446044922, 'coordinates': {'points': ((np.float64(264.82086181640625), np.float64(771.9403686523438)), (np.float64(264.82086181640625), np.float64(844.0458108517355)), (np.float64(1423.25390625), np.float64(844.0458108517355)), (np.float64(1423.25390625), np.float64(771.9403686523438))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['nor', 'vie'], 'page_number': 5, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': 'ce5d37d932a805c52b3881b10104ad8f'}, page_content='同时，这也是目前LangChain工具家族中，仅次于LangChain（109k stars）第二受欢迎的开发框 架，在GitHub上已斩获接近72k stars。'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(269.4444487731475), np.float64(863.1945907002239)), (np.float64(269.4444487731475), np.float64(1440.2779399884166)), (np.float64(1448.6111329745333), np.float64(1440.2779399884166)), (np.float64(1448.6111329745333), np.float64(863.1945907002239))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 5, 'filename': '0.pdf', 'category': 'Image', 'element_id': '233bd8622956916488f7f55bad9158d9'}, page_content='# langflow Public P main ~ P 1515 Bran © 540 Tags a edwinjosechittilappilly and jordanrfrazier * .cursor/rules .devcontainer github .vscode deploy docker docker_example docs scripts test-results @ Watch 405 ~ Y Fork 68k Starred 71.5k Add file ~ <> Code v About Langflow is a powerful tool for building © 16,032 Commits and deploying Al-powered agents and workflows. @ wwwilangflow.org multiagent agents react-flow large-language-models generative-ai chatgpt revent perm'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.7546614408493042, 'coordinates': {'points': ((np.float64(287.6041259765625), np.float64(1475.7618408203125)), (np.float64(287.6041259765625), np.float64(1506.5458256475672)), (np.float64(839.4558715820312), np.float64(1506.5458256475672)), (np.float64(839.4558715820312), np.float64(1475.7618408203125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['tgl'], 'page_number': 5, 'filename': '0.pdf', 'category': 'Title', 'element_id': '7fb1f7a00b1fa15abf3849e7a3c841c7'}, page_content='LangFlow官网：https://www.langflow.org/'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.5799580812454224, 'coordinates': {'points': ((np.float64(254.53302001953125), np.float64(1544.6092529296875)), (np.float64(254.53302001953125), np.float64(1577.3791605628453)), (np.float64(1358.5303691960628), np.float64(1577.3791605628453)), (np.float64(1358.5303691960628), np.float64(1544.6092529296875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho', 'kor'], 'page_number': 5, 'filename': '0.pdf', 'parent_id': '7fb1f7a00b1fa15abf3849e7a3c841c7', 'category': 'NarrativeText', 'element_id': 'b12072b238d21da49d70cb6251630454'}, page_content='同时，相比Dify，LangFlow功能更加完善，并且没有任何商业化的计划，可长期稳定使用。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.34985753893852234, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(1610.6737060546875)), (np.float64(206.944447643981), np.float64(1641.9624953385398)), (np.float64(637.6858301805372), np.float64(1641.9624953385398)), (np.float64(637.6858301805372), np.float64(1610.6737060546875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 5, 'filename': '0.pdf', 'parent_id': '7fb1f7a00b1fa15abf3849e7a3c841c7', 'category': 'NarrativeText', 'element_id': 'ea60bce07b613dbff867c380c94889ca'}, page_content='目前LangChain工具生态如图所示：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(77.77799009258344)), (np.float64(206.94445137731415), np.float64(877.7779567592502)), (np.float64(1448.6111996411973), np.float64(877.7779567592502)), (np.float64(1448.6111996411973), np.float64(77.77799009258344))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng', 'tgl'], 'page_number': 6, 'filename': '0.pdf', 'category': 'Image', 'element_id': 'ea5a6d1015a513b2732a2da72f1805f8'}, page_content='LangGraph Platform LangSmith Debugging COMMERCIAL Playground Integrations Prompt Management Annotation Testing LangChain LangGraph Monitoring hitecture Arc! \\'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8695740103721619, 'coordinates': {'points': ((np.float64(246.75180053710938), np.float64(902.9986572265625)), (np.float64(246.75180053710938), np.float64(984.3380126953125)), (np.float64(1396.6427658805728), np.float64(984.3380126953125)), (np.float64(1396.6427658805728), np.float64(902.9986572265625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 6, 'filename': '0.pdf', 'category': 'ListItem', 'element_id': '59ad7e7b3ceedd0bc5aedc2ffcbcf7e6'}, page_content='此外，作为底层框架本身，LangChain本身仍保持了非常快速的迭代速度，例如就在5月29号， LangChain发布最新版本，新增了目前通用智能体项目非常需要的沙盒环境（SandBox）：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(290.2777812384253), np.float64(998.6112517245291)), (np.float64(290.2777812384253), np.float64(1573.6112677661943)), (np.float64(1427.777733842592), np.float64(1573.6112677661943)), (np.float64(1427.777733842592), np.float64(998.6112517245291))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 6, 'filename': '0.pdf', 'category': 'Image', 'element_id': 'be9e43aee10dc839b600c35ff266e471'}, page_content='@ LANGCHAIN LangChain Sandbox: Run untrusted Python in your Al Agents LangChain Sandbox lets you safely run untrusted Python in your Al agents! Built on Pyodide (Python in WebAssembly), LangChain Sandbox lets you execute code securely: Isolated runtime with configurable permissions No Docker or remote code execution required Supports session-based state persistence Check out the examples (open-source): https://github.com/langchain-ai/langchain- sandbox/tree/main/examples'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8956448435783386, 'coordinates': {'points': ((np.float64(265.75714111328125), np.float64(1592.79833984375)), (np.float64(265.75714111328125), np.float64(1669.2987060546875)), (np.float64(1429.2706298828125), np.float64(1669.2987060546875)), (np.float64(1429.2706298828125), np.float64(1592.79833984375))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 6, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': '7617c9b9118a14174395b64177807314'}, page_content='同时，LangChain也是最早官宣支持谷歌A2A技术协议的开发框架，这也使得LangChain本身的先 进性一直处于整个Agent开发框架的前列。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8509567379951477, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(1705.265869140625)), (np.float64(206.944447643981), np.float64(1758.8582763671875)), (np.float64(1039.6842041015625), np.float64(1758.8582763671875)), (np.float64(1039.6842041015625), np.float64(1705.265869140625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 6, 'filename': '0.pdf', 'category': 'Title', 'element_id': 'ee38c1a4cb69ad04cfce179d78975a3d'}, page_content='4. 当下大模型开发人员必备技能：LangChain'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9323227405548096, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(1794.8642578125)), (np.float64(206.944447643981), np.float64(1913.24560546875)), (np.float64(1446.1536865234375), np.float64(1913.24560546875)), (np.float64(1446.1536865234375), np.float64(1794.8642578125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 6, 'filename': '0.pdf', 'parent_id': 'ee38c1a4cb69ad04cfce179d78975a3d', 'category': 'NarrativeText', 'element_id': 'b6e785bd4fd1979f2020d6beadda5383'}, page_content='可以说，经过了近3年的发展，目前LangChain工具生态已经非常全面，能适用于各类不同场景的开 发需求，无论是小规模实验、还是大规模商业化部署，无论是使用代码开发、还是偏向使用低代码开发 工具，LangChain工具家族都能满足开发者的需求。'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9450576305389404, 'coordinates': {'points': ((np.float64(199.5267791748047), np.float64(1943.1483154296875)), (np.float64(199.5267791748047), np.float64(2107.305419921875)), (np.float64(1439.7340087890625), np.float64(2107.305419921875)), (np.float64(1439.7340087890625), np.float64(1943.1483154296875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 6, 'filename': '0.pdf', 'parent_id': 'ee38c1a4cb69ad04cfce179d78975a3d', 'category': 'NarrativeText', 'element_id': '38f2c9eb4f07f6e70a32108f11311f7b'}, page_content='也正因如此，LangChain可以说是历经大模型Agent技术发展巨变但仍“屹立不倒”的开发工具，哪怕 今年以来OpenAI、谷歌等AI巨头纷纷下场发布全新一代Agent开发框架，但LangChian工具本身仍在很 多场景下不可替代。而相比之下，类似AotuGen、CrewAI等工具的适用面，在大模型技术飞速发展的当 下，正在逐渐减少。截止目前，LangChain仍然是目前大模型开发岗位应用最广的框架没有之一：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(77.77734342594378)), (np.float64(206.94445137731415), np.float64(617.3606542766382)), (np.float64(1448.6111329745333), np.float64(617.3606542766382)), (np.float64(1448.6111329745333), np.float64(77.77734342594378))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 7, 'filename': '0.pdf', 'category': 'Image', 'element_id': '187bad5ef2e0856d60b80d6c35412303'}, page_content='IRAE'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8859962224960327, 'coordinates': {'points': ((np.float64(198.45657348632812), np.float64(646.119384765625)), (np.float64(198.45657348632812), np.float64(721.681640625)), (np.float64(1437.74560546875), np.float64(721.681640625)), (np.float64(1437.74560546875), np.float64(646.119384765625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['vie'], 'page_number': 7, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': '7bae00db91f0b49a4bbf5b2c7aae5c32'}, page_content='同时LangChain也是很多著名的开源项目的底层开发框架，如字节前端时间开源的Deep Research 应用deerflow就是采用了LangChain&LangGraph框架：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(748.6105554745592)), (np.float64(206.94445137731415), np.float64(1506.9439372106667)), (np.float64(1448.6111329745333), np.float64(1506.9439372106667)), (np.float64(1448.6111329745333), np.float64(748.6105554745592))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 7, 'filename': '0.pdf', 'category': 'Image', 'element_id': 'b59e776a579124b8c93a25a91d59d43c'}, page_content='& deer-flow.mp4 ~ DeerFlow Deep Research at Your Fingertips > 0:00 / 1:27 int. With powerful t like , it provides instant Get Started > © Learn More © star on cittiua'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(1529.8605629224742)), (np.float64(206.94445137731415), np.float64(1979.8605841724723)), (np.float64(1448.6111996411973), np.float64(1979.8605841724723)), (np.float64(1448.6111996411973), np.float64(1529.8605629224742))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 7, 'filename': '0.pdf', 'category': 'Image', 'element_id': '6fd711431d55d0688d3fe1168f3fd0cd'}, page_content='Production Deployment docker-compose.yml Dockerfile deer-flow-api Port 8000 API Keys & Settings Full Stack Package Management web/Dockerfile Nextjs App Port 3000 uw pyprojecttom! Python Depend: package; Nodejs Deper Configuration contyaml LLM Configuration Development Local Development bootstrap.sh -d LangGraph Studio langgraph dev Port 2024 langgraphjson ‘Studio Configuration'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.6031580567359924, 'coordinates': {'points': ((np.float64(205.2946319580078), np.float64(2006.732666015625)), (np.float64(205.2946319580078), np.float64(2039.8781175587221)), (np.float64(894.9562377929688), np.float64(2039.8781175587221)), (np.float64(894.9562377929688), np.float64(2006.732666015625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 7, 'filename': '0.pdf', 'category': 'FigureCaption', 'element_id': '493e246882a257e0826f4f74ca247c7f'}, page_content='项目主页：https://github.com/bytedance/deer-flow'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.870466411113739, 'coordinates': {'points': ((np.float64(206.944447643981), np.float64(2076.877197265625)), (np.float64(206.944447643981), np.float64(2147.3650991259324)), (np.float64(1435.430908203125), np.float64(2147.3650991259324)), (np.float64(1435.430908203125), np.float64(2076.877197265625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['deu', 'vie'], 'page_number': 7, 'filename': '0.pdf', 'category': 'NarrativeText', 'element_id': 'ecfde91527954fd24ed11d94a9a6001f'}, page_content='此外如谷歌近期开源的Gemini Fullstack LangGraph Quickstart热门项目，也是使用LangGraph作为基 础框架：'),
#  Document(metadata={'source': '0.pdf', 'coordinates': {'points': ((np.float64(206.94445137731415), np.float64(77.77734342594411)), (np.float64(206.94445137731415), np.float64(1027.7773838426074)), (np.float64(1448.6111996411973), np.float64(1027.7773838426074)), (np.float64(1448.6111996411973), np.float64(77.77734342594411))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 8, 'filename': '0.pdf', 'category': 'Image', 'element_id': 'c8a3d37cc3828d623d3c2a1025ce7981'}, page_content="1 README 418 Apache-2.0license 15 Security Gemini Fullstack LangGraph Quickstart This project demonstrates a fullstack application using a React frontend and a LangGraph-powered backend agent. The agent is designed to perform comprehensive research on a user's query by dynamically generating search terms, querying the web using Google Search, reflecting on the results to identify knowledge gaps, and iteratively refining its search until it can provide a well-supported answer with citations. This application serves as an example of building research-augmented conversational Al using LangGraph and Google's Gemini models. What is the latest Google Gemini Model? Research — Generating Search Queries ~~ latest Google Gemini model as of M: Web Research Gathered 4: el y, googleblog, blog Reflection What comprehensive performance benchmarks for Google Gemini 2.5 Pro and Gemini 2.5 Flash models Web Research lated to: docsbot, datacamp, bl Searching..."),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.5420282483100891, 'coordinates': {'points': ((np.float64(241.21676635742188), np.float64(108.65188598632812)), (np.float64(241.21676635742188), np.float64(131.61920166015625)), (np.float64(713.229248046875), np.float64(131.61920166015625)), (np.float64(713.229248046875), np.float64(108.65188598632812))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 8, 'filename': '0.pdf', 'category': 'Header', 'element_id': 'fc5b38952f8c85baaa66f66041fff105'}, page_content='1 README 418 Apache-2.0license 15 Security'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8270580172538757, 'coordinates': {'points': ((np.float64(266.4343566894531), np.float64(201.54571533203125)), (np.float64(266.4343566894531), np.float64(253.49107360839844)), (np.float64(1039.4075927734375), np.float64(253.49107360839844)), (np.float64(1039.4075927734375), np.float64(201.54571533203125))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 8, 'filename': '0.pdf', 'parent_id': 'fc5b38952f8c85baaa66f66041fff105', 'category': 'Title', 'element_id': '7b90eda7f2515ef11bd4b9c90b6cff2a'}, page_content='Gemini Fullstack LangGraph Quickstart'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.9277879595756531, 'coordinates': {'points': ((np.float64(263.0469665527344), np.float64(292.79156494140625)), (np.float64(263.0469665527344), np.float64(449.0411071777344)), (np.float64(1407.900634765625), np.float64(449.0411071777344)), (np.float64(1407.900634765625), np.float64(292.79156494140625))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 8, 'filename': '0.pdf', 'parent_id': '7b90eda7f2515ef11bd4b9c90b6cff2a', 'category': 'NarrativeText', 'element_id': '0aaa2517e97267f273382fe4628a4f4f'}, page_content="This project demonstrates a fullstack application using a React frontend and a LangGraph-powered backend agent. The agent is designed to perform comprehensive research on a user's query by dynamically generating search terms, querying the web using Google Search, reflecting on the results to identify knowledge gaps, and iteratively refining its search until it can provide a well-supported answer with citations. This application serves as an example of building research-augmented conversational Al using LangGraph and Google's Gemini models."),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.8449229001998901, 'coordinates': {'points': ((np.float64(215.05172729492188), np.float64(477.121826171875)), (np.float64(215.05172729492188), np.float64(1030.051513671875)), (np.float64(1496.290283203125), np.float64(1030.051513671875)), (np.float64(1496.290283203125), np.float64(477.121826171875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['eng'], 'page_number': 8, 'filename': '0.pdf', 'category': 'Image', 'element_id': '3c2b1183f55ba6ceccc15e38559751cf'}, page_content='What is the latest Google Gemini Model? Research — Generating Search Queries ~~ latest Google Gemini model as of M: Web Research Gathered 4: el y, googleblog, blog Reflection What comprehensive performance benchmarks for Google Gemini 2.5 Pro and Gemini 2.5 Flash models Web Research lated to: docsbot, datacamp, bl Searching...'),
#  Document(metadata={'source': '0.pdf', 'detection_class_prob': 0.47461727261543274, 'coordinates': {'points': ((np.float64(216.80422973632812), np.float64(1055.3621826171875)), (np.float64(216.80422973632812), np.float64(1088.724853515625)), (np.float64(1297.5281982421875), np.float64(1088.724853515625)), (np.float64(1297.5281982421875), np.float64(1055.3621826171875))), 'system': 'PixelSpace', 'layout_width': 1656, 'layout_height': 2342}, 'last_modified': '2025-09-02T23:26:41', 'filetype': 'application/pdf', 'languages': ['zho'], 'page_number': 8, 'filename': '0.pdf', 'category': 'FigureCaption', 'element_id': 'ee3345ab7dcc70b26ab2ccc9232a18fd'}, page_content='项目主页：https://github.com/google-gemini/gemini-fullstack-langgraph-quickstart')]

# %%
from langchain_unstructured import UnstructuredLoader

loader_local = UnstructuredLoader(
    file_path=file_path,
    strategy="hi_res",  # 高分辨率模式，支持复杂文档
    infer_table_structure=True,  # 自动解析表格结构
    ocr_languages="chi_sim+eng",  # 支持中英文 OCR
    ocr_engine="paddleocr",  # 指定 PaddleOCR 作为 OCR 引擎
    poppler_path=poppler_path  # 明确指定 poppler 路径
)

docs_local = []
for doc in loader_local.lazy_load():
    docs_local.append(doc)
# Out:
# WARNING: The ocr_languages kwarg will be deprecated in a future version of unstructured. Please use languages instead.
# WARNING: Only one of languages and ocr_languages should be specified. languages is preferred. ocr_languages is marked for deprecation.
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# INFO: Reading PDF for file: 0.pdf ...
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats

# %%
import fitz
import matplotlib.patches as patches
import matplotlib.pyplot as plt
from PIL import Image

def plot_pdf_with_boxes(pdf_page, segments):
    pix = pdf_page.get_pixmap()
    pil_image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(pil_image)
    categories = set()
    category_to_color = {
        "Title": "orchid",
        "Image": "forestgreen",
        "Table": "tomato",
    }
    for segment in segments:
        points = segment["coordinates"]["points"]
        layout_width = segment["coordinates"]["layout_width"]
        layout_height = segment["coordinates"]["layout_height"]
        scaled_points = [
            (x * pix.width / layout_width, y * pix.height / layout_height)
            for x, y in points
        ]
        box_color = category_to_color.get(segment["category"], "deepskyblue")
        categories.add(segment["category"])
        rect = patches.Polygon(
            scaled_points, linewidth=1, edgecolor=box_color, facecolor="none"
        )
        ax.add_patch(rect)

    # Make legend
    legend_handles = [patches.Patch(color="deepskyblue", label="Text")]
    for category in ["Title", "Image", "Table"]:
        if category in categories:
            legend_handles.append(
                patches.Patch(color=category_to_color[category], label=category)
            )
    ax.axis("off")
    ax.legend(handles=legend_handles, loc="upper right")
    plt.tight_layout()
    plt.show()

def render_page(doc_list: list, page_number: int, print_text=True) -> None:
    pdf_page = fitz.open(file_path).load_page(page_number - 1)
    page_docs = [
        doc for doc in doc_list if doc.metadata.get("page_number") == page_number
    ]
    segments = [doc.metadata for doc in page_docs]
    plot_pdf_with_boxes(pdf_page, segments)
    if print_text:
        for doc in page_docs:
            print(f"{doc.page_content}\n")

# %%
render_page(docs_local, 1)
# Out:
# LangChain快速入门与Agent开发实战-Part
#
# 1
#
# 一、LangChain.ai工具生态介绍
#
# 本期公开课，我将为大家详细讲解元老级Agent开发工具——LangChain。
#
# 1. GPT-3时代下第一代大模型开发工具
#
# LangChain 可以称之为自 2022年底 大模型技术爆火以来的第一个真正意义上的大模型开发框架。大 模型本质上无法直接解决实际的问题，仅仅是一个能够分析、推理和生成文本的黑盒。直到现在，所有 的开发者们仍然在不断探索如何把大模型的强大能力与实际应用场景结合起来，而当时 LangChain 的出 现，直接让大模型开发变得简单起来，它将大模型开发过程中常用的功能、工具、流程等等全部封装成 一个个的组件，使开发者可以像搭乐高积木一样，快速的组合出适用于不同场景需求的大模型应用。
#
# LangChain 的首个版本于 2022年10月 开源，直到现在仍然再以一个飞快的速度不断进行迭代升
#
# 级。从一个开源 Python/TS 框架逐渐发展，形成包括“链”和“代理”等核心组件，现在已走向企业级阶
#
# 段，发展成了 LangChain AI ，其拥有目前 Agent 技术领域最大的开源生态，衍生出了多个开源项目框
#
# 架，各自都在大模型的技术领域承担着不同的开发任务角色。
#
# 从一个形象的角度来说，LangChain的功能定位其实并不是我们现在所谓的Agent开发框架，而是一 个大模型功能增强器，借助LangChain，哪怕在GPT-3模型时代，也能让模型完成对话、拥有记忆、甚至 是完成结构化输出等功能。
#
# XD Langchain The platform for reliable agents. p of the agent development lifecycle werful Al in production.
#
# LangChain官网：https://www.langchain.com/
#
# 2. 备受争议的工具功能
#
# 虽说LangChain的开源，在短时间内收获了大量的开发者用户，这也一度使得LangChain在2023年 成为最受欢迎的大模型开发工具没有之一。但每项技术都会受限于其诞生的时代背景，LangChain也不 例外。在GPT-3时代，大模型以补全模型为主，只能以类似“成语接龙”的方式对文本进行补全，并且实际 运行效果也非常不稳定。此时LangChain借助一些高层封装的API，能够让模型完成对话、调用外部工 具、甚至是结构化输出等功能，这在当时是非常大的进步，也为开发者提供了极大的便利。

# %%
render_page(docs_local, 3)
# Out:
# 3. “SREL. BARRE” 7e/D FAP GitHub Issue Ff] Reddit R28: ° “SOHEBES 3K, ALAM" reddit.com © KARAT. verbose MwA: BABE issue iS verbose (TAA—R , Issue HB KAMARA, SHEE.
#
# 而这也使得在某个时间段，LangChain的开发者大规模流失。
#
# 举个例子，为了更好的兼容不同模型的调用，谷歌ADK采用了LiteLlm作为底层模型调度框架，一 个库即可调用各类模型，而LangChain则为每个主流模型单独封装了一个库，调用不同模型的时候 需要导入不同模型对应的库，例如调用DeepSeek就需要安装 langchain-deepseek ，而调用 Gemini则需要安装 langchain-google-genai 。
#
# 3. 更加适用于当前Agent开发的LangChain工具生态
#
# 在经历了短暂的阵痛后，LangChain果断进行了大刀阔斧的改革。LangChain调整的思路非常简
#
# 单：
#
# 1. LangChain本身仍然坚守作为“模型能力增强器”的功能定位，并且逐渐稳定更新节奏和频率，虽说 实际使用LangChain进行开发的代码量仍然没变，但模块划分更加清晰、功能更加丰富和稳定，逐 步达到企业级应用水准。目前最新版LangChain的核心功能如下：
#
# 模块类别 示例功能 模型接口封装 OpenAI、Claude、Cohere、Qwen 等模型统一调用方式 输出结构化 自动从模型中解析 JSON、Schema、函数签名、文档等 Memory 管理 Buffer、Summary、Entity、Conversation Memory 等 Tool 接入 Web 搜索、SQL 数据库、Python 执行器、API 代理等 Agent 架构 ReAct、Self-Ask、OpenAI Function Agent 等调度机制 RAG 集成 多种 Retriever、Vector Store、文档拆分策略 Server/API 发布 快速将链部署为 Web 服务或 A2A Agent Debug & Callback Token 使用统计、LangSmith 可视化追踪等
#
# ✅ 所以说：LangChain 是 LLM 功能开发的「积木工厂」，不是简单框架，而是模型增强器 + 应用组装工具箱。
#
# 2. 与2023年下半年开源LangGraph，LangGraph作为基于LangChain的更高层次封装，能够更加便捷 的搭建图结构的大模型工作流，也就是现在所谓的Multi-Agent系统，而LangGraph也是目前 LangChian家族最核心的Multi-Agent开发框架。同时可以搭配LangGraph-Studio进行实时效果监 测，实际效果如下所示：

# %%
import os
import fitz
from unstructured.partition.pdf import partition_pdf

pdf_path = "0.pdf"
output_dir = "pdf_images"
os.makedirs(output_dir, exist_ok=True)

# Step 1: 提取文本/结构化内容
elements = partition_pdf(
    filename=pdf_path,
    infer_table_structure=True,  # 开启表格结构检测
    strategy="hi_res",  # 高分辨率 OCR, 适合复杂表格
    ocr_languages="chi_sim+eng",  # 中英文混合识别
    ocr_engine="paddleocr",  # 指定 PaddleOCR 引擎
    poppler_path=poppler_path  # 明确指定 poppler 路径
)

# Step 2: 提取图片并保存
doc = fitz.open(pdf_path)
image_map = {}  # 映射 page_num -> list of image paths

for page_num, page in enumerate(doc, start=1):
    image_map[page_num] = []
    for img_index, img in enumerate(page.get_images(full=True), start=1):
        xref = img[0]
        pix = fitz.Pixmap(doc, xref)
        img_path = os.path.join(output_dir, f"page{page_num}_img{img_index}.png")
        if pix.n < 5:  # RGB / Gray
            pix.save(img_path)
        else:  # CMYK 转 RGB
            pix = fitz.Pixmap(fitz.csRGB, pix)
            pix.save(img_path)
        image_map[page_num].append(img_path)

# Step 3: 转换为 Markdown
md_lines = []
inserted_images = set()  # 用来记录已经插入过的图片, 避免重复

for el in elements:
    cat = el.category
    text = el.text
    page_num = el.metadata.page_number

    if cat == "List" and text.strip().startswith("- "):
        md_lines.append(text + "\n")
    elif cat == "Title":
        md_lines.append(f"# {text}\n")
    elif cat in ["Header", "Subheader"]:
        md_lines.append(f"## {text}\n")
    elif cat == "Table":
        if hasattr(el.metadata, "text_as_html") and el.metadata.text_as_html:
            # 确保 html2text 已安装
            try:
                from html2text import html2text
                md_lines.append(html2text(el.metadata.text_as_html) + "\n")
            except ImportError:
                print("警告: html2text 模块未安装，无法转换表格 HTML。请运行 pip install html2text")
                md_lines.append(el.text + "\n")
        else:
            md_lines.append(el.text + "\n")
    elif cat == "Image":
        # 避免重复插入: 只插入当前图片对应的文件
        for img_path in image_map.get(page_num, []):
            if img_path not in inserted_images:
                md_lines.append(f"![Image](./{img_path})\n")
                inserted_images.add(img_path)
    else:
        md_lines.append(text + "\n")

# Step 4: 写入 Markdown 文件
output_md = "output.md"
with open(output_md, "w", encoding="utf-8") as f:
    f.write("\n".join(md_lines))

print(f"✅ 转换完成, 已生成 {output_md} 和 {output_dir}/ 图片文件夹")
# Out:
# WARNING: The ocr_languages kwarg will be deprecated in a future version of unstructured. Please use languages instead.
# WARNING: Only one of languages and ocr_languages should be specified. languages is preferred. ocr_languages is marked for deprecation.
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# INFO: Reading PDF for file: 0.pdf ...
# WARNING: Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# ✅ 转换完成, 已生成 output.md 和 pdf_images/ 图片文件夹
